# %%
# inspired by the work at
# https://www.kaggle.com/code/shrutimechlearn/step-by-step-pca-with-iris-dataset/notebook
# https://www.kaggle.com/code/skalskip/iris-data-visualization-and-knn-classification/notebook
# 

import numpy as np
import pandas as pd
import missingno as msno
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pandas.plotting import andrews_curves
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap



# setting seaborn for plotting
sns.set(font_scale=2)

# %%
beans = pd.read_csv('DryBeanDataset/Dry_Bean_Dataset.csv')
beans.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
beans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
beans.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860154       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %%
# Pre-processing of the data
beans.Class.replace({'Seker':0, \
                     'Barbunya':1, \
                     'Bombay':2, \
                     'Cali':3, \
                     'Dermosan':4, \
                     'Horoz':5, \
                     'Sira':6})
# plotting if there is any missing values
msno.bar(beans, figsize=(16,6))
plt.show()
print('*'*50)
print('NO MISSING VALUES')
# Out:
# **************************************************
# NO MISSING VALUES

# %%
# This is for the count of each bean type
plt.subplots(figsize=(10,5))
sns.countplot(y=beans.Class,data=beans)
plt.show()
print('*'*50)
print('There exist some class imbalances as the counts are not equal')
# Out:
# **************************************************
# There exist some class imbalances as the counts are not equal

# %%
sns.set(font_scale=2)
fig, axs = plt.subplots(4,4, figsize = (25,25))
r,c= 0,0
for i in range(0,16): # 16 features excluding the class type
    
    if c > 3: # moving to the row after
        r+=1
        c = 0
    ax = axs[r,c]
    sns.boxplot(x= beans['Class'], y=beans[beans.columns[i]],ax=ax)
    c+=1
    ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
    ax.set_xlabel('')
    
    if r != 3:
        ax.set_xticks([])
        
fig.suptitle('Distribution of each feature by bean type', fontsize = 40)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(28,28))
htmp = sns.heatmap(beans.corr(), annot=True)
plt.show()

# %%
# This is before performing PCA
print('Using KNN (K nearest neighbor) with k = 5 PCA')
x = beans.drop(['Class'], axis=1) # dropping target metric
y = beans.Class # saving target metric

x = MinMaxScaler().fit_transform(x) #normalizing data to (0,1)

# splitting data into training and testsing
# random_state=42 for reproducability
x_train, x_test, y_train, y_test = train_test_split(x, y, \
                                                    test_size = 0.33, \
                                                    random_state=42, \
                                                    stratify=y)

knn = KNeighborsClassifier() # using default No. neighbors = 5
knn.fit(x_train, y_train)

print('Train acc: ', knn.score(x_train,y_train))
print('Test acc: ', knn.score(x_test, y_test))
# Out:
# Using KNN (K nearest neighbor) with k = 5 PCA
# Train acc:  0.9358482289724751
# Test acc:  0.9136242208370436

# %%
# This is for PCA
print('Using KNN (K nearest neighbor) with k = 5 after PCA')

pca = PCA(n_components = 0.99)
x_pca = pca.fit_transform(x)
    
x_train_pca, x_test_pca, y_train_pca, y_test_pca = train_test_split(x_pca,\
                                                            y,\
                                                            test_size = 0.33,\
                                                            random_state=42,\
                                                            stratify=y)

knn_pca = KNeighborsClassifier() # using default No. neighbors = 5
knn_pca.fit(x_train_pca,y_train_pca)
print("Train acc after PCA",knn_pca.score(x_train_pca,y_train_pca))
print("Test acc after PCA",knn_pca.score(x_test_pca,y_test_pca))
# Out:
# Using KNN (K nearest neighbor) with k = 5 after PCA
# Train acc after PCA 0.9389187410900318
# Test acc after PCA 0.9122885129118433
